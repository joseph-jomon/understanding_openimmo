# %% [markdown]
# https://chatgpt.com/share/2a0baee4-dc8b-4042-a27a-fdbc1ca7a253

# %%
import xml
import xmltodict
import pandas as pd
#1. Extract Data from XML

with open('./data_openimmo/openimmo-data_127.xml') as fd:
    xml_data = xmltodict.parse(fd.read())

# Now xml_data is a Python dictionary you can work with
#print("Dictionary Keys are :", xml_data['openimmo'].keys())

############################
#2. Transform XML Data to Pandas DataFrame
df = pd.DataFrame(xml_data['openimmo'])  # Adjust 'root_element' to match your XML structure
print(xml_data['openimmo']['anbieter'].keys())
#for key, value in xml_data.items():
  #  print(f"{key}: {value}")
# Out:
# dict_keys(['anbieternr', 'firma', 'openimmo_anid', 'lizenzkennung', 'anhang', 'immobilie', 'impressum', 'impressum_strukt', 'user_defined_simplefield', 'user_defined_anyfield'])

# %% [markdown]
# # openimmo is the root element

# %%
df = pd.DataFrame(xml_data['openimmo'].keys(), columns=['openimmo_child_elements'])
print(df)
# Out:
#     openimmo_child_elements
# 0              uebertragung
# 1                  anbieter
# 2  user_defined_simplefield
# 3     user_defined_anyfield

# %% [markdown]
# # The first child of openimmo is uebertragung

# %%
df = pd.DataFrame(xml_data['openimmo']['uebertragung'].keys(), columns=['uebertragung_child_elements'])
print(df)
# @ symbol represents attributes of the element
# Out:
#   uebertragung_child_elements
# 0                        @art
# 1                     @umfang
# 2                      @modus
# 3                    @version
# 4             @sendersoftware
# 5              @senderversion
# 6                @techn_email
# 7                  @timestamp
# 8                    @regi_id

# %% [markdown]
# # Second child element and most important and heavily nested child element is anbieter

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter'].keys(), columns=['Anbieter_child_elements'])
print(df)
# Out:
#     Anbieter_child_elements
# 0                anbieternr
# 1                     firma
# 2             openimmo_anid
# 3             lizenzkennung
# 4                    anhang
# 5                 immobilie
# 6                 impressum
# 7          impressum_strukt
# 8  user_defined_simplefield
# 9     user_defined_anyfield

# %% [markdown]
# # then comes user_defined_simplefield
# dont know what this is for

# %%
df = pd.DataFrame(xml_data['openimmo']['user_defined_simplefield'].keys(), columns=['user_defined_anyfield_child_element'])
print(df)
# Out:
#   user_defined_anyfield_child_element
# 0                           @feldname

# %% [markdown]
# # then user defined anyfield
# nonetype element

# %% [markdown]
# # Here is the json view of the whole document

# %%
import xmltodict
import json

print(json.dumps(xml_data['openimmo']['anbieter'], indent=4))
# Out:
# {
#     "anbieternr": null,
#     "firma": "MusterMannFrau Immobilien",
#     "openimmo_anid": null,
#     "lizenzkennung": "ABCD13",
#     "anhang": {
#         "@location": "EXTERN",
#         "@gruppe": "BILD",
#         "anhangtitel": null,
#         "format": null,
#         "daten": {
#             "pfad": null
#         }
#     },
#     "immobilie": {
#         "objektkategorie": {
#             "nutzungsart": {
#                 "@WOHNEN": "true",
#                 "@GEWERBE": "false",
#                 "@ANLAGE": "false",
#                 "@WAZ": "false"
#             },
#             "vermarktungsart": {
#                 "@KAUF": "true",
#                 "@MIETE_PACHT": "false",
#                 "@ERBPACHT": "false",
#                 "@LEASING": "false"
#             },
#             "objektart": {
#                 "zimmer": {
#                     "@zimmertyp": "ZIMMER"
#                 },
#                 "objektart_zusatz": "Moebeliert"
#             },
#             "user_defined_simplefield": {
#                 "@feldname": ""
#             },
#             "user_defined_anyfield": null
#         },
#         "geo": {
#             "plz": null,
#             "ort": null,
#             "geokoordinaten": {
#                 "@breitengrad": "22.22",
#                 "@laengengrad": "22.22"
#             },
#             "strasse": null,
#             "hausnummer": null,
#             "bundesland": null,
#             "land": {
#                 "@iso_land": "DEU"
#             },
#             "gemeindecode": null,
#             "flur": null,
#             "flurstueck": null,
#             "gemarkung": null,
#             "etage": "1",
#             "anzahl_etagen": "3",
#             "lage_im_bau": {
#                 "@LINKS": "false",
#                 "@RECHTS": "true",
#                 "@VORNE": "true",
#                 "@HINTEN": "false"
#             },
#             "wohnungsnr": null,
#             "lage_gebiet": {
#                 "@gebiete": "NEBENZENTRUM"
#             },
#             "regionaler_zusatz": "Blumenviertel",
#             "karten_makro": "true",
#             "karten_mikro": "false",
#             "virtuelletour": "false",
#             "luftbildern": "true",
#             "user_defined_simplefield": {
#                 "@feldname": ""
#             },
#             "user_defined_anyfield": null,
#             "user_defined_extend": null
#         },
#         "kontaktperson": {
#             "email_zentrale": "foo@bar.de",
#             "email_direkt": "foo@bar.de",
#             "tel_zentrale": "1",
#             "tel_durchw": "2",
#             "tel_fax": "3",
#             "tel_handy": "4",
#             "name": null,
#             "vorname": null,
#             "titel": null,
#             "anrede": null,
#             "anrede_brief": null,
#             "firma": null,
#             "zusatzfeld": null,
#             "strasse": null,
#             "hausnummer": null,
#             "plz": null,
#             "ort": null,
#             "postfach": null,
#             "postf_plz": null,
#             "postf_ort": null,
#             "land": {
#                 "@iso_land": "DEU"
#             },
#             "email_privat": "foo@bar.de",
#             "email_sonstige": {
#                 "@emailart": "EM_DIREKT",
#                 "@bemerkung": "1",
#                 "#text": "foo@bar.de"
#             },
#             "email_feedback": "yx@y.de",
#             "tel_privat": "1",
#             "tel_sonstige": {
#                 "@telefonart": "TEL_PRIVAT",
#                 "@bemerkung": "",
#                 "#text": "1"
#             },
#             "url": null,
#             "adressfreigabe": "false",
#             "personennummer": null,
#             "immobilientreuhaenderid": "In .AT",
#             "foto": {
#                 "@location": "EXTERN",
#                 "format": "JPEG",
#                 "daten": {
#                     "pfad": "abc.jpg"
#                 }
#             },
#             "freitextfeld": null,
#             "user_defined_simplefield": {
#                 "@feldname": ""
#             },
#             "user_defined_anyfield": null,
#             "user_defined_extend": null
#         },
#         "weitere_adresse": {
#             "@adressart": "",
#             "vorname": null,
#             "name": null,
#             "titel": null,
#             "anrede": null,
#             "anrede_brief": null,
#             "firma": null,
#             "zusatzfeld": null,
#             "strasse": null,
#             "hausnummer": null,
#             "plz": null,
#             "ort": null,
#             "postfach": null,
#             "postf_plz": null,
#             "postf_ort": null,
#             "land": {
#                 "@iso_land": "DEU"
#             },
#             "email_zentrale": "foo@bar.de",
#             "email_direkt": "foo@bar.de",
#             "email_privat": "foo@bar.de",
#             "email_sonstige": {
#                 "@emailart": "EM_PRIVAT",
#                 "@bemerkung": "",
#                 "#text": "1"
#             },
#             "tel_durchw": "1",
#             "tel_zentrale": "1",
#             "tel_handy": "1",
#             "tel_fax": "1",
#             "tel_privat": "1",
#             "tel_sonstige": {
#                 "@telefonart": "TEL_DURCHW",
#                 "@bemerkung": "",
#                 "#text": "1"
#             },
#             "url": null,
#             "adressfreigabe": "false",
#             "personennummer": null,
#             "freitextfeld": null,
#             "user_defined_simplefield": {
#                 "@feldname": ""
#             },
#             "user_defined_anyfield": null,
#             "user_defined_extend": null
#         },
#         "preise": {
#             "kaufpreis": "1",
#             "kaufpreisnetto": "100000.00",
#             "kaufpreisbrutto": "119000.00",
#             "nettokaltmiete": "1",
#             "kaltmiete": "1",
#             "warmmiete": "1",
#             "nebenkosten": "1",
#             "heizkosten_enthalten": "false",
#             "heizkosten": "1",
#             "zzg_mehrwertsteuer": "true",
#             "mietzuschlaege": "1",
#             "hauptmietzinsnetto": {
#                 "@hauptmietzinsust": "106.40",
#                 "#text": "560.00"
#             },
#             "pauschalmiete": "100",
#             "betriebskostennetto": {
#                 "@betriebskostenust": "106.40",
#                 "#text": "560.00"
#             },
#             "pacht": "1",
#             "erbpacht": "1",
#             "hausgeld": "1",
#             "abstand": "1",
#             "preis_zeitraum_von": "2001-01-01",
#             "preis_zeitraum_bis": "2001-01-01",
#             "preis_zeiteinheit": {
#                 "@zeiteinheit": "JAHR"
#             },
#             "mietpreis_pro_qm": "1",
#             "kaufpreis_pro_qm": "1",
#             "provisionspflichtig": "true",
#             "provision_teilen": "false",
#             "innen_courtage": {
#                 "@mit_mwst": "false"
#             },
#             "aussen_courtage": {
#                 "@mit_mwst": "false"
#             },
#             "courtage_hinweis": "String",
#             "provisionnetto": "100",
#             "provisionbrutto": "119",
#             "waehrung": {
#                 "@iso_waehrung": "DEM"
#             },
#             "mwst_satz": "19",
#             "mwst_gesamt": "500.00",
#             "freitext_preis": null,
#             "x_fache": null,
#             "nettorendite": "10",
#             "nettorendite_soll": "10",
#             "nettorendite_ist": "10",
#             "mieteinnahmen_ist": {
#                 "@periode": "JAHR",
#                 "#text": "1"
#             },
#             "mieteinnahmen_soll": {
#                 "@periode": "JAHR",
#                 "#text": "1"
#             },
#             "erschliessungskosten": "1",
#             "kaution": "1",
#             "kaution_text": "3 monate",
#             "geschaeftsguthaben": "1",
#             "stp_carport": {
#                 "@stellplatzmiete": "1",
#                 "@stellplatzkaufpreis": "1",
#                 "@anzahl": "1"
#             },
#             "stp_duplex": {
#                 "@stellplatzmiete": "1",
#                 "@stellplatzkaufpreis": "1",
#                 "@anzahl": "1"
#             },
#             "stp_freiplatz": {
#                 "@stellplatzmiete": "1",
#                 "@stellplatzkaufpreis": "1",
#                 "@anzahl": "1"
#             },
#             "stp_garage": {
#                 "@stellplatzmiete": "1",
#                 "@stellplatzkaufpreis": "1",
#                 "@anzahl": "1"
#             },
#             "stp_parkhaus": {
#                 "@stellplatzmiete": "1",
#                 "@stellplatzkaufpreis": "1",
#                 "@anzahl": "1"
#             },
#             "stp_tiefgarage": {
#                 "@stellplatzmiete": "1",
#                 "@stellplatzkaufpreis": "1",
#                 "@anzahl": "1"
#             },
#             "stp_sonstige": {
#                 "@stellplatzmiete": "1",
#                 "@stellplatzkaufpreis": "1",
#                 "@anzahl": "1",
#                 "@platzart": "CARPORT",
#                 "@bemerkung": ""
#             },
#             "user_defined_simplefield": {
#                 "@feldname": ""
#             },
#             "user_defined_anyfield": null,
#             "user_defined_extend": {
#                 "feld": {
#                     "name": null,
#                     "wert": null,
#                     "typ": null,
#                     "modus": null
#                 }
#             }
#         },
#         "bieterverfahren": {
#             "beginn_angebotsphase": "2001-01-01",
#             "besichtigungstermin": "2001-01-01",
#             "hoechstgebot_zeigen": "false",
#             "mindestpreis": "1",
#             "user_defined_simplefield": {
#                 "@feldname": ""
#             },
#             "user_defined_anyfield": null,
#             "user_defined_extend": {
#                 "feld": {
#                     "name": null,
#                     "wert": null,
#                     "typ": null,
#                     "modus": null
#                 }
#             }
#         },
#         "versteigerung": {
#             "zwangsversteigerung": "true",
#             "aktenzeichen": "abc123",
#             "zvtermin": "2001-01-01T11:00:00",
#             "zusatztermin": "2001-01-01T11:00:00",
#             "amtsgericht": "Stadt",
#             "verkehrswert": "150000"
#         },
#         "flaechen": {
#             "wohnflaeche": "1",
#             "nutzflaeche": "1",
#             "gesamtflaeche": "1",
#             "ladenflaeche": "1",
#             "lagerflaeche": "1",
#             "verkaufsflaeche": "1",
#             "freiflaeche": "1",
#             "bueroflaeche": "1",
#             "bueroteilflaeche": "1",
#             "fensterfront": "1",
#             "verwaltungsflaeche": "1",
#             "gastroflaeche": "1",
#             "grz": "1",
#             "gfz": "1",
#             "bmz": "1",
#             "bgf": "1",
#             "grundstuecksflaeche": "1",
#             "sonstflaeche": "1",
#             "anzahl_zimmer": "1",
#             "anzahl_schlafzimmer": "1",
#             "anzahl_badezimmer": "1",
#             "anzahl_sep_wc": "1",
#             "anzahl_balkone": "1",
#             "anzahl_terrassen": "1",
#             "anzahl_logia": "1",
#             "balkon_terrasse_flaeche": "30",
#             "anzahl_wohn_schlafzimmer": "1",
#             "gartenflaeche": "1",
#             "kellerflaeche": "1",
#             "fensterfront_qm": "1",
#             "grundstuecksfront": "1",
#             "dachbodenflaeche": "1",
#             "teilbar_ab": "1",
#             "beheizbare_flaeche": "1",
#             "anzahl_stellplaetze": "1",
#             "plaetze_gastraum": "1",
#             "anzahl_betten": "1",
#             "anzahl_tagungsraeume": "1",
#             "vermietbare_flaeche": "1",
#             "anzahl_wohneinheiten": "1",
#             "anzahl_gewerbeeinheiten": "1",
#             "einliegerwohnung": "1",
#             "kubatur": "2",
#             "ausnuetzungsziffer": "1",
#             "flaechevon": "100",
#             "flaechebis": "200",
#             "user_defined_simplefield": {
#                 "@feldname": "abc"
#             },
#             "user_defined_anyfield": null,
#             "user_defined_extend": {
#                 "feld": {
#                     "name": null,
#                     "wert": null,
#                     "typ": null,
#                     "modus": null
#                 }
#             }
#         },
#         "ausstattung": {
#             "ausstatt_kategorie": "STANDARD",
#             "wg_geeignet": "false",
#             "raeume_veraenderbar": "false",
#             "bad": {
#                 "@DUSCHE": "1",
#                 "@WANNE": "1",
#                 "@FENSTER": "1",
#                 "@BIDET": "1",
#                 "@PISSOIR": "1"
#             },
#             "kueche": {
#                 "@EBK": "1",
#                 "@OFFEN": "1",
#                 "@PANTRY": "1"
#             },
#             "boden": {
#                 "@FLIESEN": "0",
#                 "@STEIN": "0",
#                 "@TEPPICH": "1",
#                 "@PARKETT": "1",
#                 "@FERTIGPARKETT": "0",
#                 "@LAMINAT": "0",
#                 "@DIELEN": "0",
#                 "@KUNSTSTOFF": "1",
#                 "@ESTRICH": "1",
#                 "@DOPPELBODEN": "1",
#                 "@LINOLEUM": "1",
#                 "@MARMOR": "1",
#                 "@TERRAKOTTA": "1",
#                 "@GRANIT": "0"
#             },
#             "kamin": "1",
#             "heizungsart": {
#                 "@OFEN": "1",
#                 "@ETAGE": "1",
#                 "@ZENTRAL": "1",
#                 "@FERN": "1",
#                 "@FUSSBODEN": "1"
#             },
#             "befeuerung": {
#                 "@OEL": "0",
#                 "@GAS": "1",
#                 "@ELEKTRO": "0",
#                 "@ALTERNATIV": "0",
#                 "@SOLAR": "1",
#                 "@ERDWAERME": "0",
#                 "@LUFTWP": "0",
#                 "@FERN": "0",
#                 "@BLOCK": "0",
#                 "@WASSER-ELEKTRO": "0",
#                 "@PELLET": "0"
#             },
#             "klimatisiert": "1",
#             "fahrstuhl": {
#                 "@PERSONEN": "1",
#                 "@LASTEN": "1"
#             },
#             "stellplatzart": {
#                 "@GARAGE": "1",
#                 "@TIEFGARAGE": "1",
#                 "@CARPORT": "1",
#                 "@FREIPLATZ": "1",
#                 "@PARKHAUS": "1",
#                 "@DUPLEX": "1"
#             },
#             "gartennutzung": "1",
#             "ausricht_balkon_terrasse": {
#                 "@NORD": "1",
#                 "@OST": "1",
#                 "@SUED": "1",
#                 "@WEST": "1",
#                 "@NORDOST": "1",
#                 "@NORDWEST": "1",
#                 "@SUEDOST": "1",
#                 "@SUEDWEST": "1"
#             },
#             "moebliert": {
#                 "@moeb": "TEIL"
#             },
#             "rollstuhlgerecht": "false",
#             "kabel_sat_tv": "false",
#             "barrierefrei": "false",
#             "sauna": "false",
#             "swimmingpool": "false",
#             "wasch_trockenraum": "false",
#             "wintergarten": "false",
#             "dv_verkabelung": "false",
#             "rampe": "false",
#             "hebebuehne": "false",
#             "kran": "false",
#             "gastterrasse": "false",
#             "stromanschlusswert": null,
#             "kantine_cafeteria": "false",
#             "teekueche": "false",
#             "hallenhoehe": "10.5",
#             "angeschl_gastronomie": {
#                 "@HOTELRESTAURANT": "false",
#                 "@BAR": "false"
#             },
#             "brauereibindung": "false",
#             "sporteinrichtungen": "false",
#             "wellnessbereich": "false",
#             "serviceleistungen": {
#                 "@BETREUTES_WOHNEN": "false",
#                 "@CATERING": "false",
#                 "@REINIGUNG": "false",
#                 "@EINKAUF": "false",
#                 "@WACHDIENST": "false"
#             },
#             "telefon_ferienimmobilie": "false",
#             "sicherheitstechnik": {
#                 "@ALARMANLAGE": "false",
#                 "@KAMERA": "false",
#                 "@POLIZEIRUF": "false"
#             },
#             "unterkellert": {
#                 "@keller": "JA"
#             },
#             "abstellraum": "false",
#             "fahrradraum": "false",
#             "rolladen": "false",
#             "dachform": {
#                 "@KRUEPPELWALMDACH": "1",
#                 "@MANSARDDACH": "1",
#                 "@PULTDACH": "1",
#                 "@SATTELDACH": "1",
#                 "@WALMDACH": "1",
#                 "@FLACHDACH": "1",
#                 "@PYRAMIDENDACH": "1"
#             },
#             "bauweise": {
#                 "@MASSIV": "1",
#                 "@FERTIGTEILE": "1",
#                 "@HOLZ": "1"
#             },
#             "ausbaustufe": {
#                 "@BAUSATZHAUS": "1",
#                 "@AUSBAUHAUS": "1",
#                 "@SCHLUESSELFERTIGMITKELLER": "1",
#                 "@SCHLUESSELFERTIGOHNEBODENPLATTE": "1",
#                 "@SCHLUESSELFERTIGMITBODENPLATTE": "1"
#             },
#             "energietyp": {
#                 "@PASSIVHAUS": "1",
#                 "@NIEDRIGENERGIE": "1",
#                 "@NEUBAUSTANDARD": "1",
#                 "@KFW40": "1",
#                 "@KFW60": "1"
#             },
#             "bibliothek": "1",
#             "dachboden": "1",
#             "gaestewc": "1",
#             "kabelkanaele": "1",
#             "seniorengerecht": "1",
#             "user_defined_simplefield": {
#                 "@feldname": ""
#             },
#             "user_defined_anyfield": null,
#             "user_defined_extend": {
#                 "feld": {
#                     "name": null,
#                     "wert": null,
#                     "typ": null,
#                     "modus": null
#                 }
#             }
#         },
#         "zustand_angaben": {
#             "baujahr": null,
#             "letztemodernisierung": null,
#             "zustand": {
#                 "@zustand_art": "ENTKERNT"
#             },
#             "alter": {
#                 "@alter_attr": "ALTBAU"
#             },
#             "bebaubar_nach": {
#                 "@bebaubar_attr": "34_NACHBARSCHAFT"
#             },
#             "erschliessung": {
#                 "@erschl_attr": "TEILERSCHLOSSEN"
#             },
#             "erschliessung_umfang": null,
#             "bauzone": null,
#             "altlasten": null,
#             "energiepass": {
#                 "epart": "VERBRAUCH",
#                 "gueltig_bis": "01-2024",
#                 "energieverbrauchkennwert": "80",
#                 "mitwarmwasser": "false",
#                 "endenergiebedarf": null,
#                 "primaerenergietraeger": "GAS",
#                 "stromwert": null,
#                 "waermewert": "80",
#                 "wertklasse": "C",
#                 "ausstelldatum": "2014-06-01",
#                 "jahrgang": "2014",
#                 "gebaeudeart": "wohn"
#             },
#             "verkaufstatus": null,
#             "user_defined_simplefield": {
#                 "@feldname": ""
#             },
#             "user_defined_anyfield": null,
#             "user_defined_extend": null
#         },
#         "bewertung": {
#             "feld": {
#                 "name": "abc",
#                 "wert": "100",
#                 "typ": "int",
#                 "modus": "kauf"
#             }
#         },
#         "infrastruktur": {
#             "zulieferung": "false",
#             "ausblick": {
#                 "@blick": "BERGE"
#             },
#             "distanzen": {
#                 "@distanz_zu": "HAUPTSCHULE",
#                 "#text": "22.00"
#             },
#             "distanzen_sport": {
#                 "@distanz_zu_sport": "SEE",
#                 "#text": "15"
#             },
#             "user_defined_simplefield": {
#                 "@feldname": ""
#             },
#             "user_defined_anyfield": null,
#             "user_defined_extend": null
#         },
#         "freitexte": {
#             "objekttitel": "Sch\u00ef\u00bf\u00bdnes Appartment im Stadtzentrum",
#             "dreizeiler": null,
#             "lage": null,
#             "ausstatt_beschr": null,
#             "objektbeschreibung": null,
#             "sonstige_angaben": "Hier k\u00ef\u00bf\u00bdnnen Hinweise auf die Regelung im Fernabsatzgesetz stehen.",
#             "objekt_text": {
#                 "@lang": "en",
#                 "#text": "Nice appartment in the inner city"
#             }
#         },
#         "anhaenge": {
#             "anhang": {
#                 "@location": "INTERN",
#                 "@gruppe": "TITELBILD",
#                 "anhangtitel": "Frontansicht des Hauses",
#                 "format": "JPEG",
#                 "check": {
#                     "@ctype": "DATETIME",
#                     "#text": "2011-09-01T12:15:05"
#                 },
#                 "daten": {
#                     "pfad": "abc.jpg"
#                 }
#             },
#             "user_defined_simplefield": {
#                 "@feldname": ""
#             },
#             "user_defined_anyfield": null
#         },
#         "verwaltung_objekt": {
#             "objektadresse_freigeben": "false",
#             "verfuegbar_ab": null,
#             "abdatum": "2001-01-01",
#             "bisdatum": "2001-01-01",
#             "min_mietdauer": {
#                 "@min_dauer": "MONAT"
#             },
#             "max_mietdauer": {
#                 "@max_dauer": "MONAT"
#             },
#             "versteigerungstermin": "2001-01-01",
#             "wbs_sozialwohnung": "false",
#             "vermietet": "false",
#             "gruppennummer": null,
#             "zugang": null,
#             "laufzeit": "10",
#             "max_personen": "10",
#             "nichtraucher": "true",
#             "haustiere": "true",
#             "geschlecht": {
#                 "@geschl_attr": "EGAL"
#             },
#             "denkmalgeschuetzt": "false",
#             "als_ferien": "true",
#             "gewerbliche_nutzung": "true",
#             "branchen": null,
#             "hochhaus": "false",
#             "user_defined_simplefield": {
#                 "@feldname": ""
#             },
#             "user_defined_anyfield": null
#         },
#         "verwaltung_techn": {
#             "objektnr_intern": null,
#             "objektnr_extern": null,
#             "aktion": {
#                 "@aktionart": "CHANGE"
#             },
#             "aktiv_von": "2001-01-01",
#             "aktiv_bis": "2001-01-03",
#             "openimmo_obid": "111",
#             "kennung_ursprung": null,
#             "stand_vom": "2001-02-03",
#             "weitergabe_generell": "true",
#             "weitergabe_positiv": null,
#             "weitergabe_negativ": null,
#             "gruppen_kennung": "001",
#             "master": {
#                 "@visible": "false",
#                 "#text": "001"
#             },
#             "sprache": null,
#             "user_defined_simplefield": {
#                 "@feldname": ""
#             },
#             "user_defined_anyfield": null,
#             "user_defined_extend": null
#         },
#         "user_defined_simplefield": {
#             "@feldname": ""
#         },
#         "user_defined_anyfield": {
#             "plaintext": [
#                 {
#                     "@fieldname": "objektart",
#                     "@fieldvalue": "Etagenwohnung"
#                 },
#                 {
#                     "@fieldname": "auslandsregion",
#                     "@fieldvalue": "Canillo"
#                 },
#                 {
#                     "@fieldname": "headline2",
#                     "@fieldvalue": " Einfamilienhaus in Dortmund"
#                 }
#             ],
#             "flag": [
#                 {
#                     "@fieldname": "balkon",
#                     "@fieldvalue": "true"
#                 },
#                 {
#                     "@fieldname": "terrasse",
#                     "@fieldvalue": "false"
#                 }
#             ]
#         },
#         "user_defined_extend": null
#     },
#     "impressum": null,
#     "impressum_strukt": {
#         "firmenname": null,
#         "firmenanschrift": null,
#         "telefon": null,
#         "vertretungsberechtigter": null,
#         "berufsaufsichtsbehoerde": null,
#         "handelsregister": null,
#         "handelsregister_nr": null,
#         "umsst-id": null,
#         "steuernummer": null,
#         "weiteres": null
#     },
#     "user_defined_simplefield": {
#         "@feldname": ""
#     },
#     "user_defined_anyfield": null
# }

# %%
import xmltodict
import json

# Parse XML to dictionary
with open('./data_openimmo/openimmo-data_127.xml') as fd:
    xml_data = xmltodict.parse(fd.read())

# Pretty-print the dictionary to view its structure
print(json.dumps(xml_data, indent=4))
# Out:
# {
#     "openimmo": {
#         "uebertragung": {
#             "@art": "ONLINE",
#             "@umfang": "VOLL",
#             "@modus": "NEW",
#             "@version": "1.2.7",
#             "@sendersoftware": "OIGEN",
#             "@senderversion": "0.9",
#             "@techn_email": "",
#             "@timestamp": "2014-06-01T10:00:00",
#             "@regi_id": "ABCD143"
#         },
#         "anbieter": {
#             "anbieternr": null,
#             "firma": "MusterMannFrau Immobilien",
#             "openimmo_anid": null,
#             "lizenzkennung": "ABCD13",
#             "anhang": {
#                 "@location": "EXTERN",
#                 "@gruppe": "BILD",
#                 "anhangtitel": null,
#                 "format": null,
#                 "daten": {
#                     "pfad": null
#                 }
#             },
#             "immobilie": {
#                 "objektkategorie": {
#                     "nutzungsart": {
#                         "@WOHNEN": "true",
#                         "@GEWERBE": "false",
#                         "@ANLAGE": "false",
#                         "@WAZ": "false"
#                     },
#                     "vermarktungsart": {
#                         "@KAUF": "true",
#                         "@MIETE_PACHT": "false",
#                         "@ERBPACHT": "false",
#                         "@LEASING": "false"
#                     },
#                     "objektart": {
#                         "zimmer": {
#                             "@zimmertyp": "ZIMMER"
#                         },
#                         "objektart_zusatz": "Moebeliert"
#                     },
#                     "user_defined_simplefield": {
#                         "@feldname": ""
#                     },
#                     "user_defined_anyfield": null
#                 },
#                 "geo": {
#                     "plz": null,
#                     "ort": null,
#                     "geokoordinaten": {
#                         "@breitengrad": "22.22",
#                         "@laengengrad": "22.22"
#                     },
#                     "strasse": null,
#                     "hausnummer": null,
#                     "bundesland": null,
#                     "land": {
#                         "@iso_land": "DEU"
#                     },
#                     "gemeindecode": null,
#                     "flur": null,
#                     "flurstueck": null,
#                     "gemarkung": null,
#                     "etage": "1",
#                     "anzahl_etagen": "3",
#                     "lage_im_bau": {
#                         "@LINKS": "false",
#                         "@RECHTS": "true",
#                         "@VORNE": "true",
#                         "@HINTEN": "false"
#                     },
#                     "wohnungsnr": null,
#                     "lage_gebiet": {
#                         "@gebiete": "NEBENZENTRUM"
#                     },
#                     "regionaler_zusatz": "Blumenviertel",
#                     "karten_makro": "true",
#                     "karten_mikro": "false",
#                     "virtuelletour": "false",
#                     "luftbildern": "true",
#                     "user_defined_simplefield": {
#                         "@feldname": ""
#                     },
#                     "user_defined_anyfield": null,
#                     "user_defined_extend": null
#                 },
#                 "kontaktperson": {
#                     "email_zentrale": "foo@bar.de",
#                     "email_direkt": "foo@bar.de",
#                     "tel_zentrale": "1",
#                     "tel_durchw": "2",
#                     "tel_fax": "3",
#                     "tel_handy": "4",
#                     "name": null,
#                     "vorname": null,
#                     "titel": null,
#                     "anrede": null,
#                     "anrede_brief": null,
#                     "firma": null,
#                     "zusatzfeld": null,
#                     "strasse": null,
#                     "hausnummer": null,
#                     "plz": null,
#                     "ort": null,
#                     "postfach": null,
#                     "postf_plz": null,
#                     "postf_ort": null,
#                     "land": {
#                         "@iso_land": "DEU"
#                     },
#                     "email_privat": "foo@bar.de",
#                     "email_sonstige": {
#                         "@emailart": "EM_DIREKT",
#                         "@bemerkung": "1",
#                         "#text": "foo@bar.de"
#                     },
#                     "email_feedback": "yx@y.de",
#                     "tel_privat": "1",
#                     "tel_sonstige": {
#                         "@telefonart": "TEL_PRIVAT",
#                         "@bemerkung": "",
#                         "#text": "1"
#                     },
#                     "url": null,
#                     "adressfreigabe": "false",
#                     "personennummer": null,
#                     "immobilientreuhaenderid": "In .AT",
#                     "foto": {
#                         "@location": "EXTERN",
#                         "format": "JPEG",
#                         "daten": {
#                             "pfad": "abc.jpg"
#                         }
#                     },
#                     "freitextfeld": null,
#                     "user_defined_simplefield": {
#                         "@feldname": ""
#                     },
#                     "user_defined_anyfield": null,
#                     "user_defined_extend": null
#                 },
#                 "weitere_adresse": {
#                     "@adressart": "",
#                     "vorname": null,
#                     "name": null,
#                     "titel": null,
#                     "anrede": null,
#                     "anrede_brief": null,
#                     "firma": null,
#                     "zusatzfeld": null,
#                     "strasse": null,
#                     "hausnummer": null,
#                     "plz": null,
#                     "ort": null,
#                     "postfach": null,
#                     "postf_plz": null,
#                     "postf_ort": null,
#                     "land": {
#                         "@iso_land": "DEU"
#                     },
#                     "email_zentrale": "foo@bar.de",
#                     "email_direkt": "foo@bar.de",
#                     "email_privat": "foo@bar.de",
#                     "email_sonstige": {
#                         "@emailart": "EM_PRIVAT",
#                         "@bemerkung": "",
#                         "#text": "1"
#                     },
#                     "tel_durchw": "1",
#                     "tel_zentrale": "1",
#                     "tel_handy": "1",
#                     "tel_fax": "1",
#                     "tel_privat": "1",
#                     "tel_sonstige": {
#                         "@telefonart": "TEL_DURCHW",
#                         "@bemerkung": "",
#                         "#text": "1"
#                     },
#                     "url": null,
#                     "adressfreigabe": "false",
#                     "personennummer": null,
#                     "freitextfeld": null,
#                     "user_defined_simplefield": {
#                         "@feldname": ""
#                     },
#                     "user_defined_anyfield": null,
#                     "user_defined_extend": null
#                 },
#                 "preise": {
#                     "kaufpreis": "1",
#                     "kaufpreisnetto": "100000.00",
#                     "kaufpreisbrutto": "119000.00",
#                     "nettokaltmiete": "1",
#                     "kaltmiete": "1",
#                     "warmmiete": "1",
#                     "nebenkosten": "1",
#                     "heizkosten_enthalten": "false",
#                     "heizkosten": "1",
#                     "zzg_mehrwertsteuer": "true",
#                     "mietzuschlaege": "1",
#                     "hauptmietzinsnetto": {
#                         "@hauptmietzinsust": "106.40",
#                         "#text": "560.00"
#                     },
#                     "pauschalmiete": "100",
#                     "betriebskostennetto": {
#                         "@betriebskostenust": "106.40",
#                         "#text": "560.00"
#                     },
#                     "pacht": "1",
#                     "erbpacht": "1",
#                     "hausgeld": "1",
#                     "abstand": "1",
#                     "preis_zeitraum_von": "2001-01-01",
#                     "preis_zeitraum_bis": "2001-01-01",
#                     "preis_zeiteinheit": {
#                         "@zeiteinheit": "JAHR"
#                     },
#                     "mietpreis_pro_qm": "1",
#                     "kaufpreis_pro_qm": "1",
#                     "provisionspflichtig": "true",
#                     "provision_teilen": "false",
#                     "innen_courtage": {
#                         "@mit_mwst": "false"
#                     },
#                     "aussen_courtage": {
#                         "@mit_mwst": "false"
#                     },
#                     "courtage_hinweis": "String",
#                     "provisionnetto": "100",
#                     "provisionbrutto": "119",
#                     "waehrung": {
#                         "@iso_waehrung": "DEM"
#                     },
#                     "mwst_satz": "19",
#                     "mwst_gesamt": "500.00",
#                     "freitext_preis": null,
#                     "x_fache": null,
#                     "nettorendite": "10",
#                     "nettorendite_soll": "10",
#                     "nettorendite_ist": "10",
#                     "mieteinnahmen_ist": {
#                         "@periode": "JAHR",
#                         "#text": "1"
#                     },
#                     "mieteinnahmen_soll": {
#                         "@periode": "JAHR",
#                         "#text": "1"
#                     },
#                     "erschliessungskosten": "1",
#                     "kaution": "1",
#                     "kaution_text": "3 monate",
#                     "geschaeftsguthaben": "1",
#                     "stp_carport": {
#                         "@stellplatzmiete": "1",
#                         "@stellplatzkaufpreis": "1",
#                         "@anzahl": "1"
#                     },
#                     "stp_duplex": {
#                         "@stellplatzmiete": "1",
#                         "@stellplatzkaufpreis": "1",
#                         "@anzahl": "1"
#                     },
#                     "stp_freiplatz": {
#                         "@stellplatzmiete": "1",
#                         "@stellplatzkaufpreis": "1",
#                         "@anzahl": "1"
#                     },
#                     "stp_garage": {
#                         "@stellplatzmiete": "1",
#                         "@stellplatzkaufpreis": "1",
#                         "@anzahl": "1"
#                     },
#                     "stp_parkhaus": {
#                         "@stellplatzmiete": "1",
#                         "@stellplatzkaufpreis": "1",
#                         "@anzahl": "1"
#                     },
#                     "stp_tiefgarage": {
#                         "@stellplatzmiete": "1",
#                         "@stellplatzkaufpreis": "1",
#                         "@anzahl": "1"
#                     },
#                     "stp_sonstige": {
#                         "@stellplatzmiete": "1",
#                         "@stellplatzkaufpreis": "1",
#                         "@anzahl": "1",
#                         "@platzart": "CARPORT",
#                         "@bemerkung": ""
#                     },
#                     "user_defined_simplefield": {
#                         "@feldname": ""
#                     },
#                     "user_defined_anyfield": null,
#                     "user_defined_extend": {
#                         "feld": {
#                             "name": null,
#                             "wert": null,
#                             "typ": null,
#                             "modus": null
#                         }
#                     }
#                 },
#                 "bieterverfahren": {
#                     "beginn_angebotsphase": "2001-01-01",
#                     "besichtigungstermin": "2001-01-01",
#                     "hoechstgebot_zeigen": "false",
#                     "mindestpreis": "1",
#                     "user_defined_simplefield": {
#                         "@feldname": ""
#                     },
#                     "user_defined_anyfield": null,
#                     "user_defined_extend": {
#                         "feld": {
#                             "name": null,
#                             "wert": null,
#                             "typ": null,
#                             "modus": null
#                         }
#                     }
#                 },
#                 "versteigerung": {
#                     "zwangsversteigerung": "true",
#                     "aktenzeichen": "abc123",
#                     "zvtermin": "2001-01-01T11:00:00",
#                     "zusatztermin": "2001-01-01T11:00:00",
#                     "amtsgericht": "Stadt",
#                     "verkehrswert": "150000"
#                 },
#                 "flaechen": {
#                     "wohnflaeche": "1",
#                     "nutzflaeche": "1",
#                     "gesamtflaeche": "1",
#                     "ladenflaeche": "1",
#                     "lagerflaeche": "1",
#                     "verkaufsflaeche": "1",
#                     "freiflaeche": "1",
#                     "bueroflaeche": "1",
#                     "bueroteilflaeche": "1",
#                     "fensterfront": "1",
#                     "verwaltungsflaeche": "1",
#                     "gastroflaeche": "1",
#                     "grz": "1",
#                     "gfz": "1",
#                     "bmz": "1",
#                     "bgf": "1",
#                     "grundstuecksflaeche": "1",
#                     "sonstflaeche": "1",
#                     "anzahl_zimmer": "1",
#                     "anzahl_schlafzimmer": "1",
#                     "anzahl_badezimmer": "1",
#                     "anzahl_sep_wc": "1",
#                     "anzahl_balkone": "1",
#                     "anzahl_terrassen": "1",
#                     "anzahl_logia": "1",
#                     "balkon_terrasse_flaeche": "30",
#                     "anzahl_wohn_schlafzimmer": "1",
#                     "gartenflaeche": "1",
#                     "kellerflaeche": "1",
#                     "fensterfront_qm": "1",
#                     "grundstuecksfront": "1",
#                     "dachbodenflaeche": "1",
#                     "teilbar_ab": "1",
#                     "beheizbare_flaeche": "1",
#                     "anzahl_stellplaetze": "1",
#                     "plaetze_gastraum": "1",
#                     "anzahl_betten": "1",
#                     "anzahl_tagungsraeume": "1",
#                     "vermietbare_flaeche": "1",
#                     "anzahl_wohneinheiten": "1",
#                     "anzahl_gewerbeeinheiten": "1",
#                     "einliegerwohnung": "1",
#                     "kubatur": "2",
#                     "ausnuetzungsziffer": "1",
#                     "flaechevon": "100",
#                     "flaechebis": "200",
#                     "user_defined_simplefield": {
#                         "@feldname": "abc"
#                     },
#                     "user_defined_anyfield": null,
#                     "user_defined_extend": {
#                         "feld": {
#                             "name": null,
#                             "wert": null,
#                             "typ": null,
#                             "modus": null
#                         }
#                     }
#                 },
#                 "ausstattung": {
#                     "ausstatt_kategorie": "STANDARD",
#                     "wg_geeignet": "false",
#                     "raeume_veraenderbar": "false",
#                     "bad": {
#                         "@DUSCHE": "1",
#                         "@WANNE": "1",
#                         "@FENSTER": "1",
#                         "@BIDET": "1",
#                         "@PISSOIR": "1"
#                     },
#                     "kueche": {
#                         "@EBK": "1",
#                         "@OFFEN": "1",
#                         "@PANTRY": "1"
#                     },
#                     "boden": {
#                         "@FLIESEN": "0",
#                         "@STEIN": "0",
#                         "@TEPPICH": "1",
#                         "@PARKETT": "1",
#                         "@FERTIGPARKETT": "0",
#                         "@LAMINAT": "0",
#                         "@DIELEN": "0",
#                         "@KUNSTSTOFF": "1",
#                         "@ESTRICH": "1",
#                         "@DOPPELBODEN": "1",
#                         "@LINOLEUM": "1",
#                         "@MARMOR": "1",
#                         "@TERRAKOTTA": "1",
#                         "@GRANIT": "0"
#                     },
#                     "kamin": "1",
#                     "heizungsart": {
#                         "@OFEN": "1",
#                         "@ETAGE": "1",
#                         "@ZENTRAL": "1",
#                         "@FERN": "1",
#                         "@FUSSBODEN": "1"
#                     },
#                     "befeuerung": {
#                         "@OEL": "0",
#                         "@GAS": "1",
#                         "@ELEKTRO": "0",
#                         "@ALTERNATIV": "0",
#                         "@SOLAR": "1",
#                         "@ERDWAERME": "0",
#                         "@LUFTWP": "0",
#                         "@FERN": "0",
#                         "@BLOCK": "0",
#                         "@WASSER-ELEKTRO": "0",
#                         "@PELLET": "0"
#                     },
#                     "klimatisiert": "1",
#                     "fahrstuhl": {
#                         "@PERSONEN": "1",
#                         "@LASTEN": "1"
#                     },
#                     "stellplatzart": {
#                         "@GARAGE": "1",
#                         "@TIEFGARAGE": "1",
#                         "@CARPORT": "1",
#                         "@FREIPLATZ": "1",
#                         "@PARKHAUS": "1",
#                         "@DUPLEX": "1"
#                     },
#                     "gartennutzung": "1",
#                     "ausricht_balkon_terrasse": {
#                         "@NORD": "1",
#                         "@OST": "1",
#                         "@SUED": "1",
#                         "@WEST": "1",
#                         "@NORDOST": "1",
#                         "@NORDWEST": "1",
#                         "@SUEDOST": "1",
#                         "@SUEDWEST": "1"
#                     },
#                     "moebliert": {
#                         "@moeb": "TEIL"
#                     },
#                     "rollstuhlgerecht": "false",
#                     "kabel_sat_tv": "false",
#                     "barrierefrei": "false",
#                     "sauna": "false",
#                     "swimmingpool": "false",
#                     "wasch_trockenraum": "false",
#                     "wintergarten": "false",
#                     "dv_verkabelung": "false",
#                     "rampe": "false",
#                     "hebebuehne": "false",
#                     "kran": "false",
#                     "gastterrasse": "false",
#                     "stromanschlusswert": null,
#                     "kantine_cafeteria": "false",
#                     "teekueche": "false",
#                     "hallenhoehe": "10.5",
#                     "angeschl_gastronomie": {
#                         "@HOTELRESTAURANT": "false",
#                         "@BAR": "false"
#                     },
#                     "brauereibindung": "false",
#                     "sporteinrichtungen": "false",
#                     "wellnessbereich": "false",
#                     "serviceleistungen": {
#                         "@BETREUTES_WOHNEN": "false",
#                         "@CATERING": "false",
#                         "@REINIGUNG": "false",
#                         "@EINKAUF": "false",
#                         "@WACHDIENST": "false"
#                     },
#                     "telefon_ferienimmobilie": "false",
#                     "sicherheitstechnik": {
#                         "@ALARMANLAGE": "false",
#                         "@KAMERA": "false",
#                         "@POLIZEIRUF": "false"
#                     },
#                     "unterkellert": {
#                         "@keller": "JA"
#                     },
#                     "abstellraum": "false",
#                     "fahrradraum": "false",
#                     "rolladen": "false",
#                     "dachform": {
#                         "@KRUEPPELWALMDACH": "1",
#                         "@MANSARDDACH": "1",
#                         "@PULTDACH": "1",
#                         "@SATTELDACH": "1",
#                         "@WALMDACH": "1",
#                         "@FLACHDACH": "1",
#                         "@PYRAMIDENDACH": "1"
#                     },
#                     "bauweise": {
#                         "@MASSIV": "1",
#                         "@FERTIGTEILE": "1",
#                         "@HOLZ": "1"
#                     },
#                     "ausbaustufe": {
#                         "@BAUSATZHAUS": "1",
#                         "@AUSBAUHAUS": "1",
#                         "@SCHLUESSELFERTIGMITKELLER": "1",
#                         "@SCHLUESSELFERTIGOHNEBODENPLATTE": "1",
#                         "@SCHLUESSELFERTIGMITBODENPLATTE": "1"
#                     },
#                     "energietyp": {
#                         "@PASSIVHAUS": "1",
#                         "@NIEDRIGENERGIE": "1",
#                         "@NEUBAUSTANDARD": "1",
#                         "@KFW40": "1",
#                         "@KFW60": "1"
#                     },
#                     "bibliothek": "1",
#                     "dachboden": "1",
#                     "gaestewc": "1",
#                     "kabelkanaele": "1",
#                     "seniorengerecht": "1",
#                     "user_defined_simplefield": {
#                         "@feldname": ""
#                     },
#                     "user_defined_anyfield": null,
#                     "user_defined_extend": {
#                         "feld": {
#                             "name": null,
#                             "wert": null,
#                             "typ": null,
#                             "modus": null
#                         }
#                     }
#                 },
#                 "zustand_angaben": {
#                     "baujahr": null,
#                     "letztemodernisierung": null,
#                     "zustand": {
#                         "@zustand_art": "ENTKERNT"
#                     },
#                     "alter": {
#                         "@alter_attr": "ALTBAU"
#                     },
#                     "bebaubar_nach": {
#                         "@bebaubar_attr": "34_NACHBARSCHAFT"
#                     },
#                     "erschliessung": {
#                         "@erschl_attr": "TEILERSCHLOSSEN"
#                     },
#                     "erschliessung_umfang": null,
#                     "bauzone": null,
#                     "altlasten": null,
#                     "energiepass": {
#                         "epart": "VERBRAUCH",
#                         "gueltig_bis": "01-2024",
#                         "energieverbrauchkennwert": "80",
#                         "mitwarmwasser": "false",
#                         "endenergiebedarf": null,
#                         "primaerenergietraeger": "GAS",
#                         "stromwert": null,
#                         "waermewert": "80",
#                         "wertklasse": "C",
#                         "ausstelldatum": "2014-06-01",
#                         "jahrgang": "2014",
#                         "gebaeudeart": "wohn"
#                     },
#                     "verkaufstatus": null,
#                     "user_defined_simplefield": {
#                         "@feldname": ""
#                     },
#                     "user_defined_anyfield": null,
#                     "user_defined_extend": null
#                 },
#                 "bewertung": {
#                     "feld": {
#                         "name": "abc",
#                         "wert": "100",
#                         "typ": "int",
#                         "modus": "kauf"
#                     }
#                 },
#                 "infrastruktur": {
#                     "zulieferung": "false",
#                     "ausblick": {
#                         "@blick": "BERGE"
#                     },
#                     "distanzen": {
#                         "@distanz_zu": "HAUPTSCHULE",
#                         "#text": "22.00"
#                     },
#                     "distanzen_sport": {
#                         "@distanz_zu_sport": "SEE",
#                         "#text": "15"
#                     },
#                     "user_defined_simplefield": {
#                         "@feldname": ""
#                     },
#                     "user_defined_anyfield": null,
#                     "user_defined_extend": null
#                 },
#                 "freitexte": {
#                     "objekttitel": "Sch\u00ef\u00bf\u00bdnes Appartment im Stadtzentrum",
#                     "dreizeiler": null,
#                     "lage": null,
#                     "ausstatt_beschr": null,
#                     "objektbeschreibung": null,
#                     "sonstige_angaben": "Hier k\u00ef\u00bf\u00bdnnen Hinweise auf die Regelung im Fernabsatzgesetz stehen.",
#                     "objekt_text": {
#                         "@lang": "en",
#                         "#text": "Nice appartment in the inner city"
#                     }
#                 },
#                 "anhaenge": {
#                     "anhang": {
#                         "@location": "INTERN",
#                         "@gruppe": "TITELBILD",
#                         "anhangtitel": "Frontansicht des Hauses",
#                         "format": "JPEG",
#                         "check": {
#                             "@ctype": "DATETIME",
#                             "#text": "2011-09-01T12:15:05"
#                         },
#                         "daten": {
#                             "pfad": "abc.jpg"
#                         }
#                     },
#                     "user_defined_simplefield": {
#                         "@feldname": ""
#                     },
#                     "user_defined_anyfield": null
#                 },
#                 "verwaltung_objekt": {
#                     "objektadresse_freigeben": "false",
#                     "verfuegbar_ab": null,
#                     "abdatum": "2001-01-01",
#                     "bisdatum": "2001-01-01",
#                     "min_mietdauer": {
#                         "@min_dauer": "MONAT"
#                     },
#                     "max_mietdauer": {
#                         "@max_dauer": "MONAT"
#                     },
#                     "versteigerungstermin": "2001-01-01",
#                     "wbs_sozialwohnung": "false",
#                     "vermietet": "false",
#                     "gruppennummer": null,
#                     "zugang": null,
#                     "laufzeit": "10",
#                     "max_personen": "10",
#                     "nichtraucher": "true",
#                     "haustiere": "true",
#                     "geschlecht": {
#                         "@geschl_attr": "EGAL"
#                     },
#                     "denkmalgeschuetzt": "false",
#                     "als_ferien": "true",
#                     "gewerbliche_nutzung": "true",
#                     "branchen": null,
#                     "hochhaus": "false",
#                     "user_defined_simplefield": {
#                         "@feldname": ""
#                     },
#                     "user_defined_anyfield": null
#                 },
#                 "verwaltung_techn": {
#                     "objektnr_intern": null,
#                     "objektnr_extern": null,
#                     "aktion": {
#                         "@aktionart": "CHANGE"
#                     },
#                     "aktiv_von": "2001-01-01",
#                     "aktiv_bis": "2001-01-03",
#                     "openimmo_obid": "111",
#                     "kennung_ursprung": null,
#                     "stand_vom": "2001-02-03",
#                     "weitergabe_generell": "true",
#                     "weitergabe_positiv": null,
#                     "weitergabe_negativ": null,
#                     "gruppen_kennung": "001",
#                     "master": {
#                         "@visible": "false",
#                         "#text": "001"
#                     },
#                     "sprache": null,
#                     "user_defined_simplefield": {
#                         "@feldname": ""
#                     },
#                     "user_defined_anyfield": null,
#                     "user_defined_extend": null
#                 },
#                 "user_defined_simplefield": {
#                     "@feldname": ""
#                 },
#                 "user_defined_anyfield": {
#                     "plaintext": [
#                         {
#                             "@fieldname": "objektart",
#                             "@fieldvalue": "Etagenwohnung"
#                         },
#                         {
#                             "@fieldname": "auslandsregion",
#                             "@fieldvalue": "Canillo"
#                         },
#                         {
#                             "@fieldname": "headline2",
#                             "@fieldvalue": " Einfamilienhaus in Dortmund"
#                         }
#                     ],
#                     "flag": [
#                         {
#                             "@fieldname": "balkon",
#                             "@fieldvalue": "true"
#                         },
#                         {
#                             "@fieldname": "terrasse",
#                             "@fieldvalue": "false"
#                         }
#                     ]
#                 },
#                 "user_defined_extend": null
#             },
#             "impressum": null,
#             "impressum_strukt": {
#                 "firmenname": null,
#                 "firmenanschrift": null,
#                 "telefon": null,
#                 "vertretungsberechtigter": null,
#                 "berufsaufsichtsbehoerde": null,
#                 "handelsregister": null,
#                 "handelsregister_nr": null,
#                 "umsst-id": null,
#                 "steuernummer": null,
#                 "weiteres": null
#             },
#             "user_defined_simplefield": {
#                 "@feldname": ""
#             },
#             "user_defined_anyfield": null
#         },
#         "user_defined_simplefield": {
#             "@feldname": ""
#         },
#         "user_defined_anyfield": null
#     }
# }

# %% [markdown]
# # Going to explore child elements of anbieter element
# ## list of all child elements of anbieter

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter'].keys(), columns=['Anbieter_child_elements'])
print(df)
# Out:
#     Anbieter_child_elements
# 0                anbieternr
# 1                     firma
# 2             openimmo_anid
# 3             lizenzkennung
# 4                    anhang
# 5                 immobilie
# 6                 impressum
# 7          impressum_strukt
# 8  user_defined_simplefield
# 9     user_defined_anyfield

# %% [markdown]
# ## 5th child element of anbieter  = anhang

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['anhang'].keys(), columns=['Anbieter_child_element--anhang'])
print(df)
# Out:
#   Anbieter_child_element--anhang
# 0                      @location
# 1                        @gruppe
# 2                    anhangtitel
# 3                         format
# 4                          daten

# %% [markdown]
# ## sixth and important child element of anbieter = immobilie

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie'].keys(), columns=['Anbieter_child_element--immobilie'])
print(df)
# Out:
#    Anbieter_child_element--immobilie
# 0                    objektkategorie
# 1                                geo
# 2                      kontaktperson
# 3                    weitere_adresse
# 4                             preise
# 5                    bieterverfahren
# 6                      versteigerung
# 7                           flaechen
# 8                        ausstattung
# 9                    zustand_angaben
# 10                         bewertung
# 11                     infrastruktur
# 12                         freitexte
# 13                          anhaenge
# 14                 verwaltung_objekt
# 15                  verwaltung_techn
# 16          user_defined_simplefield
# 17             user_defined_anyfield
# 18               user_defined_extend

# %% [markdown]
# ## seventh child element of anbeter = impressum_strukt

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['impressum_strukt'].keys(), columns=['Anbieter_child_element--impressum_strukt'])
print(df)
# Out:
#   Anbieter_child_element--impressum_strukt
# 0                               firmenname
# 1                          firmenanschrift
# 2                                  telefon
# 3                  vertretungsberechtigter
# 4                  berufsaufsichtsbehoerde
# 5                          handelsregister
# 6                       handelsregister_nr
# 7                                 umsst-id
# 8                             steuernummer
# 9                                 weiteres

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['user_defined_simplefield'].keys(), columns=['Anbieter_child_elements'])
print(df)
# Out:
#   Anbieter_child_elements
# 0               @feldname

# %% [markdown]
# ## Going in to elements of immobilie

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie'].keys(), columns=['Anbieter_child_element--immobilie'])
print(df)
# Out:
#    Anbieter_child_element--immobilie
# 0                    objektkategorie
# 1                                geo
# 2                      kontaktperson
# 3                    weitere_adresse
# 4                             preise
# 5                    bieterverfahren
# 6                      versteigerung
# 7                           flaechen
# 8                        ausstattung
# 9                    zustand_angaben
# 10                         bewertung
# 11                     infrastruktur
# 12                         freitexte
# 13                          anhaenge
# 14                 verwaltung_objekt
# 15                  verwaltung_techn
# 16          user_defined_simplefield
# 17             user_defined_anyfield
# 18               user_defined_extend

# %% [markdown]
# ## child element of immobilie--objektkategorie

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['objektkategorie'].keys(), columns=['immobilie_child_element--objektkategorie'])
print(df)
# Out:
#   immobilie_child_element--objektkategorie
# 0                              nutzungsart
# 1                          vermarktungsart
# 2                                objektart
# 3                 user_defined_simplefield
# 4                    user_defined_anyfield

# %% [markdown]
# ## child element of immobilie--geo

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['geo'].keys(), columns=['immobilie_child_element--geo'])
print(df)
# Out:
#    immobilie_child_element--geo
# 0                           plz
# 1                           ort
# 2                geokoordinaten
# 3                       strasse
# 4                    hausnummer
# 5                    bundesland
# 6                          land
# 7                  gemeindecode
# 8                          flur
# 9                    flurstueck
# 10                    gemarkung
# 11                        etage
# 12                anzahl_etagen
# 13                  lage_im_bau
# 14                   wohnungsnr
# 15                  lage_gebiet
# 16            regionaler_zusatz
# 17                 karten_makro
# 18                 karten_mikro
# 19                virtuelletour
# 20                  luftbildern
# 21     user_defined_simplefield
# 22        user_defined_anyfield
# 23          user_defined_extend

# %% [markdown]
# ## child element of immobilie--kontaktperson

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['kontaktperson'].keys(), columns=['immobilie_child_element--kontaktperson'])
print(df)
# Out:
#    immobilie_child_element--kontaktperson
# 0                          email_zentrale
# 1                            email_direkt
# 2                            tel_zentrale
# 3                              tel_durchw
# 4                                 tel_fax
# 5                               tel_handy
# 6                                    name
# 7                                 vorname
# 8                                   titel
# 9                                  anrede
# 10                           anrede_brief
# 11                                  firma
# 12                             zusatzfeld
# 13                                strasse
# 14                             hausnummer
# 15                                    plz
# 16                                    ort
# 17                               postfach
# 18                              postf_plz
# 19                              postf_ort
# 20                                   land
# 21                           email_privat
# 22                         email_sonstige
# 23                         email_feedback
# 24                             tel_privat
# 25                           tel_sonstige
# 26                                    url
# 27                         adressfreigabe
# 28                         personennummer
# 29                immobilientreuhaenderid
# 30                                   foto
# 31                           freitextfeld
# 32               user_defined_simplefield
# 33                  user_defined_anyfield
# 34                    user_defined_extend

# %% [markdown]
# ## child element of immobilie-->weitere_adresse

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['weitere_adresse'].keys(), columns=['immobilie_child_element--weitere_adresse'])
print(df)
# Out:
#    immobilie_child_element--weitere_adresse
# 0                                @adressart
# 1                                   vorname
# 2                                      name
# 3                                     titel
# 4                                    anrede
# 5                              anrede_brief
# 6                                     firma
# 7                                zusatzfeld
# 8                                   strasse
# 9                                hausnummer
# 10                                      plz
# 11                                      ort
# 12                                 postfach
# 13                                postf_plz
# 14                                postf_ort
# 15                                     land
# 16                           email_zentrale
# 17                             email_direkt
# 18                             email_privat
# 19                           email_sonstige
# 20                               tel_durchw
# 21                             tel_zentrale
# 22                                tel_handy
# 23                                  tel_fax
# 24                               tel_privat
# 25                             tel_sonstige
# 26                                      url
# 27                           adressfreigabe
# 28                           personennummer
# 29                             freitextfeld
# 30                 user_defined_simplefield
# 31                    user_defined_anyfield
# 32                      user_defined_extend

# %% [markdown]
# ## child element of immobilie-->preise

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['preise'].keys(), columns=['immobilie_child_element--preise'])
print(df)
# Out:
#    immobilie_child_element--preise
# 0                        kaufpreis
# 1                   kaufpreisnetto
# 2                  kaufpreisbrutto
# 3                   nettokaltmiete
# 4                        kaltmiete
# 5                        warmmiete
# 6                      nebenkosten
# 7             heizkosten_enthalten
# 8                       heizkosten
# 9               zzg_mehrwertsteuer
# 10                  mietzuschlaege
# 11              hauptmietzinsnetto
# 12                   pauschalmiete
# 13             betriebskostennetto
# 14                           pacht
# 15                        erbpacht
# 16                        hausgeld
# 17                         abstand
# 18              preis_zeitraum_von
# 19              preis_zeitraum_bis
# 20               preis_zeiteinheit
# 21                mietpreis_pro_qm
# 22                kaufpreis_pro_qm
# 23             provisionspflichtig
# 24                provision_teilen
# 25                  innen_courtage
# 26                 aussen_courtage
# 27                courtage_hinweis
# 28                  provisionnetto
# 29                 provisionbrutto
# 30                        waehrung
# 31                       mwst_satz
# 32                     mwst_gesamt
# 33                  freitext_preis
# 34                         x_fache
# 35                    nettorendite
# 36               nettorendite_soll
# 37                nettorendite_ist
# 38               mieteinnahmen_ist
# 39              mieteinnahmen_soll
# 40            erschliessungskosten
# 41                         kaution
# 42                    kaution_text
# 43              geschaeftsguthaben
# 44                     stp_carport
# 45                      stp_duplex
# 46                   stp_freiplatz
# 47                      stp_garage
# 48                    stp_parkhaus
# 49                  stp_tiefgarage
# 50                    stp_sonstige
# 51        user_defined_simplefield
# 52           user_defined_anyfield
# 53             user_defined_extend

# %% [markdown]
# ## child element of immobilie-->bieterverfahren

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['bieterverfahren'].keys(), columns=['immobilie_child_element--bieterverfahren'])
print(df)
# Out:
#   immobilie_child_element--bieterverfahren
# 0                     beginn_angebotsphase
# 1                      besichtigungstermin
# 2                      hoechstgebot_zeigen
# 3                             mindestpreis
# 4                 user_defined_simplefield
# 5                    user_defined_anyfield
# 6                      user_defined_extend

# %% [markdown]
# ## child element of immobilie-->versteigerung

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['versteigerung'].keys(), columns=['immobilie_child_element--versteigerung'])
print(df)
# Out:
#   immobilie_child_element--versteigerung
# 0                    zwangsversteigerung
# 1                           aktenzeichen
# 2                               zvtermin
# 3                           zusatztermin
# 4                            amtsgericht
# 5                           verkehrswert

# %% [markdown]
# ## child element of immobilie-->flaechen

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['flaechen'].keys(), columns=['immobilie_child_element--flaechen'])
print(df)
# Out:
#    immobilie_child_element--flaechen
# 0                        wohnflaeche
# 1                        nutzflaeche
# 2                      gesamtflaeche
# 3                       ladenflaeche
# 4                       lagerflaeche
# 5                    verkaufsflaeche
# 6                        freiflaeche
# 7                       bueroflaeche
# 8                   bueroteilflaeche
# 9                       fensterfront
# 10                verwaltungsflaeche
# 11                     gastroflaeche
# 12                               grz
# 13                               gfz
# 14                               bmz
# 15                               bgf
# 16               grundstuecksflaeche
# 17                      sonstflaeche
# 18                     anzahl_zimmer
# 19               anzahl_schlafzimmer
# 20                 anzahl_badezimmer
# 21                     anzahl_sep_wc
# 22                    anzahl_balkone
# 23                  anzahl_terrassen
# 24                      anzahl_logia
# 25           balkon_terrasse_flaeche
# 26          anzahl_wohn_schlafzimmer
# 27                     gartenflaeche
# 28                     kellerflaeche
# 29                   fensterfront_qm
# 30                 grundstuecksfront
# 31                  dachbodenflaeche
# 32                        teilbar_ab
# 33                beheizbare_flaeche
# 34               anzahl_stellplaetze
# 35                  plaetze_gastraum
# 36                     anzahl_betten
# 37              anzahl_tagungsraeume
# 38               vermietbare_flaeche
# 39              anzahl_wohneinheiten
# 40           anzahl_gewerbeeinheiten
# 41                  einliegerwohnung
# 42                           kubatur
# 43                ausnuetzungsziffer
# 44                        flaechevon
# 45                        flaechebis
# 46          user_defined_simplefield
# 47             user_defined_anyfield
# 48               user_defined_extend

# %% [markdown]
# ## child element of immobilie-->ausstattung

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['ausstattung'].keys(), columns=['immobilie_child_element--ausstattung'])
print(df)
# Out:
#    immobilie_child_element--ausstattung
# 0                    ausstatt_kategorie
# 1                           wg_geeignet
# 2                   raeume_veraenderbar
# 3                                   bad
# 4                                kueche
# 5                                 boden
# 6                                 kamin
# 7                           heizungsart
# 8                            befeuerung
# 9                          klimatisiert
# 10                            fahrstuhl
# 11                        stellplatzart
# 12                        gartennutzung
# 13             ausricht_balkon_terrasse
# 14                            moebliert
# 15                     rollstuhlgerecht
# 16                         kabel_sat_tv
# 17                         barrierefrei
# 18                                sauna
# 19                         swimmingpool
# 20                    wasch_trockenraum
# 21                         wintergarten
# 22                       dv_verkabelung
# 23                                rampe
# 24                           hebebuehne
# 25                                 kran
# 26                         gastterrasse
# 27                   stromanschlusswert
# 28                    kantine_cafeteria
# 29                            teekueche
# 30                          hallenhoehe
# 31                 angeschl_gastronomie
# 32                      brauereibindung
# 33                   sporteinrichtungen
# 34                      wellnessbereich
# 35                    serviceleistungen
# 36              telefon_ferienimmobilie
# 37                   sicherheitstechnik
# 38                         unterkellert
# 39                          abstellraum
# 40                          fahrradraum
# 41                             rolladen
# 42                             dachform
# 43                             bauweise
# 44                          ausbaustufe
# 45                           energietyp
# 46                           bibliothek
# 47                            dachboden
# 48                             gaestewc
# 49                         kabelkanaele
# 50                      seniorengerecht
# 51             user_defined_simplefield
# 52                user_defined_anyfield
# 53                  user_defined_extend

# %% [markdown]
# ## child element of immobilie-->zustand_angaben

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['zustand_angaben'].keys(), columns=['immobilie_child_element--zustand_angaben'])
print(df)
# Out:
#    immobilie_child_element--zustand_angaben
# 0                                   baujahr
# 1                      letztemodernisierung
# 2                                   zustand
# 3                                     alter
# 4                             bebaubar_nach
# 5                             erschliessung
# 6                      erschliessung_umfang
# 7                                   bauzone
# 8                                 altlasten
# 9                               energiepass
# 10                            verkaufstatus
# 11                 user_defined_simplefield
# 12                    user_defined_anyfield
# 13                      user_defined_extend

# %% [markdown]
# ## child element of immobilie-->bewertung

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['bewertung'].keys(), columns=['immobilie_child_element--bewertung'])
print(df)
# Out:
#   immobilie_child_element--bewertung
# 0                               feld

# %% [markdown]
# ## child element of immobilie-->infrastruktur

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['infrastruktur'].keys(), columns=['immobilie_child_element--infrastruktur'])
print(df)
# Out:
#   immobilie_child_element--infrastruktur
# 0                            zulieferung
# 1                               ausblick
# 2                              distanzen
# 3                        distanzen_sport
# 4               user_defined_simplefield
# 5                  user_defined_anyfield
# 6                    user_defined_extend

# %% [markdown]
# ## child element of immobilie-->freitexte

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['freitexte'].keys(), columns=['immobilie_child_element--freitexte'])
print(df)
# Out:
#   immobilie_child_element--freitexte
# 0                        objekttitel
# 1                         dreizeiler
# 2                               lage
# 3                    ausstatt_beschr
# 4                 objektbeschreibung
# 5                   sonstige_angaben
# 6                        objekt_text

# %% [markdown]
# ## child element of immobilie-->anhaenge

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['anhaenge'].keys(), columns=['immobilie_child_element--anhaenge'])
print(df)
# Out:
#   immobilie_child_element--anhaenge
# 0                            anhang
# 1          user_defined_simplefield
# 2             user_defined_anyfield

# %% [markdown]
# ## child element of immobilie-->verwaltung_objekt

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['verwaltung_objekt'].keys(), columns=['immobilie_child_element--verwaltung_objekt'])
print(df)
# Out:
#    immobilie_child_element--verwaltung_objekt
# 0                     objektadresse_freigeben
# 1                               verfuegbar_ab
# 2                                     abdatum
# 3                                    bisdatum
# 4                               min_mietdauer
# 5                               max_mietdauer
# 6                        versteigerungstermin
# 7                           wbs_sozialwohnung
# 8                                   vermietet
# 9                               gruppennummer
# 10                                     zugang
# 11                                   laufzeit
# 12                               max_personen
# 13                               nichtraucher
# 14                                  haustiere
# 15                                 geschlecht
# 16                          denkmalgeschuetzt
# 17                                 als_ferien
# 18                        gewerbliche_nutzung
# 19                                   branchen
# 20                                   hochhaus
# 21                   user_defined_simplefield
# 22                      user_defined_anyfield

# %% [markdown]
# ## child element of immobilie-->verwaltung_techn

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['verwaltung_techn'].keys(), columns=['immobilie_child_element--verwaltung_techn'])
print(df)
# Out:
#    immobilie_child_element--verwaltung_techn
# 0                            objektnr_intern
# 1                            objektnr_extern
# 2                                     aktion
# 3                                  aktiv_von
# 4                                  aktiv_bis
# 5                              openimmo_obid
# 6                           kennung_ursprung
# 7                                  stand_vom
# 8                        weitergabe_generell
# 9                         weitergabe_positiv
# 10                        weitergabe_negativ
# 11                           gruppen_kennung
# 12                                    master
# 13                                   sprache
# 14                  user_defined_simplefield
# 15                     user_defined_anyfield
# 16                       user_defined_extend

# %% [markdown]
# ## this field contains plaintext like objektart, etagenwohnung etc ..............

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['user_defined_anyfield'].keys(), columns=['immobilie_child_element--user_defined_anyfield'])
print(df)
# Out:
#   immobilie_child_element--user_defined_anyfield
# 0                                      plaintext
# 1                                           flag

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['user_defined_anyfield']['plaintext'])
print(df)
# Out:
#        @fieldname                   @fieldvalue
# 0       objektart                 Etagenwohnung
# 1  auslandsregion                       Canillo
# 2       headline2   Einfamilienhaus in Dortmund

# %%
df = pd.DataFrame(xml_data['openimmo']['anbieter']['immobilie']['user_defined_anyfield']['flag'])
print(df)
# Out:
#   @fieldname @fieldvalue
# 0     balkon        true
# 1   terrasse       false
